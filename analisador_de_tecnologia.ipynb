# %% [markdown]
# <a href="https://colab.research.google.com/github/maryreginaf15/Programacao-Ia-Generativa/blob/main/analisador_de_tecnologia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1 importação das bibliotecas

import spacy # biblioteca p/ texto em numero
import nltk # biblioteca p/  probabilidade para prever o sentimento da pessoa
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
# 2 Preparação

# !python -m spacy download pt_core_news_sm
nltk.download('vader_lexicon')


nlp = spacy.load("pt_core_news_sm")
termometro_lntk = SentimentIntensityAnalyzer()
# Out:
# Collecting pt-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pt_core_news_sm-3.8.0/pt_core_news_sm-3.8.0-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 82.7 MB/s eta 0:00:00
# Installing collected packages: pt-core-news-sm
# Successfully installed pt-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pt_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
# 4 Dados

frases_tecnologia = [
"O sistema da empresa trava todo dia e atrapalha meu trabalho.",
"O sistema que a empresa disponibiliza deu bug ontem e hoje de novo.",
"O aplicativo estava instável e acabou travando no meio do uso.",
"A interface dos aplicativos da empresa é boa, mas ainda pode melhorar bastante.",
"O novo sistema implantado é bom, mas trava com frequência e isso irrita."
]

# %%
# 3 Escala de sentimentos (Para a NLTK não dar nota zero no Português) aqui que faz as curadorias
pesos_extras = {
    "intuitivo" : 1.0, "rapido": 2.0, "estavel" : 4.0,
    "bug" : -0.5, "crash" : -0.6, "travou" : -0.9
}

#Atualizar o dicionario interno do nltk vom as palavras em Português
termometro_lntk.lexicon.update(pesos_extras)

# %%
#  5 Execucaco Integrada

print(f"{'PALAVRAS QUE MAIS SAEM EM TECNOLOGIA':130} | {'NOTA':<6} | {'SENTIMENTO'}") #<70 é o espaçamento
print("_" * 150)

for texto in frases_tecnologia:
    #Passo A: spacy limpa o texto
    doc = nlp(texto.lower()) # convertendo para minusculo
    palavras_uteis = {token.lemma_ for token in doc if not token.is_stop and not token.is_punct}
    frase_limpa = " ".join(palavras_uteis)

    #Passo B: NLTK mede o sentimento
    #NLTK recebe o texto limpo pelo spacy

    nota = termometro_lntk.polarity_scores(frase_limpa)['compound']

    if nota >= 0.1:
        resultado = "😊😊 POSITIVO"
    elif nota <= -0.1:
        resultado = "🤬🤬 NEGATIVO"
    else:
        resultado = "🤨🤨 NEUTRO"

    print(f"{texto:<130} | {nota:<6.1f} | {resultado}")
# Out:
# PALAVRAS QUE MAIS SAEM EM TECNOLOGIA                                                                                               | NOTA   | SENTIMENTO
# ______________________________________________________________________________________________________________________________________________________
# O sistema da empresa trava todo dia e atrapalha meu trabalho.                                                                      | 0.0    | 🤨🤨 NEUTRO
# O sistema que a empresa disponibiliza deu bug ontem e hoje de novo.                                                                | -0.1   | 🤬🤬 NEGATIVO
# O aplicativo estava instável e acabou travando no meio do uso.                                                                     | 0.0    | 🤨🤨 NEUTRO
# A interface dos aplicativos da empresa é boa, mas ainda pode melhorar bastante.                                                    | 0.0    | 🤨🤨 NEUTRO
# O novo sistema implantado é bom, mas trava com frequência e isso irrita.                                                           | 0.0    | 🤨🤨 NEUTRO
